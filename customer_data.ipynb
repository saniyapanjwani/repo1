# %% [markdown]
# CUSTOMER_DATA PROJECT

# %% [markdown]
# IMPORTING NECESSORY LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\panjwani saniya\Downloads\customer_data.csv")

# %%
data
# Out:
#        Age  Gender   AnnualIncome  NumberOfPurchases ProductCategory  \
# 0     40.0  Female   66120.267939                8.0     Electronics
# 1     20.0  Female   23579.773583                4.0      Home Goods
# 2     27.0  Female  127821.306432               11.0      Home Goods
# 3     24.0  Female  137798.623120               19.0          Beauty
# 4     31.0  Female   99300.964220               19.0        Clothing
# ...    ...     ...            ...                ...             ...
# 1495  39.0  Female   65048.141834               13.0     Electronics
# 1496  67.0  Female   28775.331069               18.0      Home Goods
# 1497  40.0  Female   57363.247541                7.0          Sports
# 1498  63.0    Male  134021.775532               16.0      Home Goods
# 1499  50.0    Male   52625.665974               13.0     Electronics
#
#       TimeSpentOnWebsite LoyaltyProgram  DiscountsAvailed PurchaseStatus
# ...

# %% [markdown]
# EDA(EXPLORATORY DATA ANALYSIS)

# %%
data.shape
# Out:
# (1500, 9)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Age                   float64
# Gender                 object
# AnnualIncome          float64
# NumberOfPurchases     float64
# ProductCategory        object
# TimeSpentOnWebsite    float64
# LoyaltyProgram         object
# DiscountsAvailed        int64
# PurchaseStatus         object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1495 non-null   float64
#  1   Gender              1500 non-null   object
#  2   AnnualIncome        1495 non-null   float64
#  3   NumberOfPurchases   1495 non-null   float64
#  4   ProductCategory     1500 non-null   object
#  5   TimeSpentOnWebsite  1495 non-null   float64
#  6   LoyaltyProgram      1500 non-null   object
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 105.6+ KB

# %%
data.describe()
# Out:
#                Age   AnnualIncome  NumberOfPurchases  TimeSpentOnWebsite  \
# count  1495.000000    1495.000000        1495.000000         1495.000000
# mean     44.309699   84250.575795          10.418729           30.496235
# std      15.543686   37667.360933           5.892038           16.973948
# min      18.000000   20001.512518           0.000000            1.037023
# 25%      31.000000   52847.266358           5.000000           16.227049
# 50%      45.000000   83842.444820          11.000000           30.957377
# 75%      57.000000  117167.772858          15.000000           44.373182
# max      70.000000  149785.176481          20.000000           59.991105
#
#        DiscountsAvailed
# count       1500.000000
# mean           2.555333
# std            1.705152
# min            0.000000
# 25%            1.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    757
# Male      743
# Name: count, dtype: int64

# %%
categorical_cols=("Gender","ProductCategory","LoyaltyProgram")

# %%
for i in categorical_cols:
    print("Unique value for ",":")
    print(data[i].value_counts())
    print("/n")
# Out:
# Unique value for  :
# Gender
# Female    757
# Male      743
# Name: count, dtype: int64
# /n
# Unique value for  :
# ProductCategory
# Clothing       331
# Sports         321
# Electronics    289
# Beauty         286
# Home Goods     273
# Name: count, dtype: int64
# /n
# Unique value for  :
# LoyaltyProgram
# No     1010
# Yes     490
# Name: count, dtype: int64
# /n

# %%
data.isnull().sum()
# Out:
# Age                   5
# Gender                0
# AnnualIncome          5
# NumberOfPurchases     5
# ProductCategory       0
# TimeSpentOnWebsite    5
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
sns.heatmap(data.isnull(),cbar=True,cmap="YlGnBu")
plt.title("Missing values in dataset")
plt.show()

# %%
data['Age']=data['Age'].fillna(data["Age"].mean())

# %%
data['AnnualIncome']=data['AnnualIncome'].fillna(data['AnnualIncome'].mean())

# %%
data["NumberOfPurchases"]=data['NumberOfPurchases'].fillna(data['NumberOfPurchases'].mean())

# %%
data['TimeSpentOnWebsite']=data['TimeSpentOnWebsite'].fillna(data['TimeSpentOnWebsite'].mean())

# %%
sns.heatmap(data.isnull(),cbar=True,cmap="YlGnBu")
plt.title("Missing values in dataset")
plt.show()

# %%
sns.barplot(data['ProductCategory'].value_counts())
plt.title("value counts for product category")
plt.show()

# %%
sns.barplot(data['Gender'].value_counts())
plt.title("value counts for Gender")
plt.show()

# %%
sns.barplot(data['LoyaltyProgram'].value_counts())
plt.title("value counts for Loyalty program")
plt.show()

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
sns.boxplot(x='Age',y='TimeSpentOnWebsite',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSpentOnWebsite'>

# %%
sns.histplot('Age')
# Out:
# <Axes: ylabel='Count'>

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
data.value_counts()
# Out:
# Age   Gender  AnnualIncome   NumberOfPurchases  ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 50.0  Male    74383.402333   13.0               Clothing         52.095368           No              2                 No                2
# 48.0  Male    61203.056413   13.0               Clothing         24.813928           No              3                 No                2
# 49.0  Female  21213.110578   11.0               Electronics      18.673823           No              3                 No                2
#               70898.340763   12.0               Sports           25.716824           No              4                 No                2
# 36.0  Female  64278.541656   19.0               Clothing         18.873765           No              0                 No                2
#                                                                                                                                         ..
# ...

# %% [markdown]
# CHECKING FOR OUTLIERS

# %%
sns.boxplot(data['Age'])
plt.title("boxplot of age")
plt.show()

# %%
sns.boxplot(data['AnnualIncome'])
plt.title("boxplot of annual income")
plt.show()

# %%
sns.boxplot(data['NumberOfPurchases'])
plt.title("boxplot of NumberOfPurchases")
plt.show()

# %%
sns.boxplot(data['TimeSpentOnWebsite'])
plt.title("TimeSpentOnWebsite")
plt.show()

# %% [markdown]
# ENCODING THE DATA

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data['Gender']=enc.fit_transform(data['Gender'])

# %%
data['ProductCategory']=enc.fit_transform(data['ProductCategory'])

# %%
data['LoyaltyProgram']=enc.fit_transform(data['LoyaltyProgram'])

# %%
data
# Out:
#        Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0     40.0       0   66120.267939                8.0                2
# 1     20.0       0   23579.773583                4.0                3
# 2     27.0       0  127821.306432               11.0                3
# 3     24.0       0  137798.623120               19.0                0
# 4     31.0       0   99300.964220               19.0                1
# ...    ...     ...            ...                ...              ...
# 1495  39.0       0   65048.141834               13.0                2
# 1496  67.0       0   28775.331069               18.0                3
# 1497  40.0       0   57363.247541                7.0                4
# 1498  63.0       1  134021.775532               16.0                3
# 1499  50.0       1   52625.665974               13.0                2
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed PurchaseStatus
# ...

# %% [markdown]
# TARGET VARIABLE

# %%
x=data.drop("PurchaseStatus",axis=1)

# %%
x
# Out:
#        Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0     40.0       0   66120.267939                8.0                2
# 1     20.0       0   23579.773583                4.0                3
# 2     27.0       0  127821.306432               11.0                3
# 3     24.0       0  137798.623120               19.0                0
# 4     31.0       0   99300.964220               19.0                1
# ...    ...     ...            ...                ...              ...
# 1495  39.0       0   65048.141834               13.0                2
# 1496  67.0       0   28775.331069               18.0                3
# 1497  40.0       0   57363.247541                7.0                4
# 1498  63.0       1  134021.775532               16.0                3
# 1499  50.0       1   52625.665974               13.0                2
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed
# 0              30.568601               0                 5
# ...

# %%
y=data['PurchaseStatus']

# %%
y
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 1495    Yes
# 1496    Yes
# 1497     No
# 1498    Yes
# 1499    Yes
# Name: PurchaseStatus, Length: 1500, dtype: object

# %% [markdown]
# TRAIN AND TESTING THE MODEL

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=12)

# %%
x_train
# Out:
#        Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 948   52.0       1   25838.468869                9.0                4
# 786   34.0       0   68252.415047               20.0                3
# 362   62.0       1  139162.580659               14.0                0
# 613   22.0       1  112695.986582               13.0                1
# 533   36.0       1  111998.521516               15.0                1
# ...    ...     ...            ...                ...              ...
# 432   43.0       1  113869.221966               12.0                2
# 1283  31.0       1   76895.972659               10.0                0
# 1265  49.0       0   21213.110578               11.0                2
# 1277  59.0       0  102717.876017                9.0                2
# 1414  69.0       0   96162.422499               17.0                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed
# 948             2.019995               1                 0
# ...

# %%
x_test
# Out:
#        Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1160  30.0       0  131433.303410                1.0                4
# 667   54.0       1   50209.961997                2.0                2
# 949   50.0       1  100181.869021                0.0                1
# 1243  43.0       1  129388.181901               14.0                2
# 101   24.0       1   98084.638651               19.0                2
# ...    ...     ...            ...                ...              ...
# 577   49.0       0  143685.018710                9.0                3
# 1394  45.0       1  149200.290557                7.0                0
# 895   28.0       0   66413.814716                8.0                1
# 568   26.0       0  128438.797610                3.0                4
# 1231  28.0       1   39105.152246               10.0                1
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed
# 1160            8.409344               0                 0
# ...

# %%
y_train
# Out:
# 948      No
# 786     Yes
# 362     Yes
# 613     Yes
# 533     Yes
#        ...
# 432      No
# 1283     No
# 1265     No
# 1277     No
# 1414    Yes
# Name: PurchaseStatus, Length: 1200, dtype: object

# %%
y_test
# Out:
# 1160     No
# 667      No
# 949     Yes
# 1243    Yes
# 101      No
#        ...
# 577     Yes
# 1394     No
# 895     Yes
# 568      No
# 1231    Yes
# Name: PurchaseStatus, Length: 300, dtype: object

# %% [markdown]
# APPLYING THE MODEL (CLASSIFICATION PROBLEM)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.88

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.9166666666666666
